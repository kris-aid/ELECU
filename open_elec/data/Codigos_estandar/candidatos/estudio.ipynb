# %%
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("candidatos_matrix.csv")
df
# Out:
#                                Unnamed: 0  2002          2004          2006  \
# 0                         CHAVEZ  MATILDE   NaN           NaN  5.021650e+12
# 1        ALDAZ DEL SALTO  CARLOS NAPOLEON   NaN           NaN  3.020000e+12
# 2                             ALIX VIVERO   NaN           NaN           NaN
# 3                           ANGEL MUENTES   NaN           NaN           NaN
# 4              ANNABELLE  BARZOLA SANCHEZ   NaN           NaN           NaN
# ...                                   ...   ...           ...           ...
# 168214      ZURITA VINCES CARMEN ANGELICA   NaN           NaN           NaN
# 168215     ZURITA VINCES EPIFANIO DOMINGO   NaN           NaN           NaN
# 168216     ZURITA VIZCAINO JOSE FRANCISCO   NaN           NaN           NaN
# 168217        ZURITA YEPEZ MARIA CRISTINA   NaN           NaN           NaN
# 168218         ZURITA ZUNIGA JOSE ERNESTO   NaN  6.181400e+12           NaN
#
#         2007          2009  2013  2014  2017     2019  2021     2023
# 0        NaN           NaN   NaN   NaN   NaN      NaN   NaN      NaN
# 1        NaN           NaN   NaN   NaN   NaN      NaN   NaN      NaN
# 2        NaN           NaN   NaN   NaN   NaN   5814.0   NaN      NaN
# 3        NaN           NaN   NaN   NaN   NaN  39620.0   NaN      NaN
# 4        NaN           NaN   NaN   NaN   NaN  34657.0   NaN      NaN
# ...      ...           ...   ...   ...   ...      ...   ...      ...
# 168214   NaN           NaN   NaN   NaN   NaN      NaN   NaN  39234.0
# 168215   NaN           NaN   NaN   NaN   NaN      NaN   NaN  18599.0
# 168216   NaN  6.040051e+12   NaN   NaN   NaN      NaN   NaN      NaN
# 168217   NaN           NaN   NaN   NaN   NaN      NaN   NaN  25409.0
# 168218   NaN  6.181400e+12   NaN   NaN   NaN      NaN   NaN      NaN
#
# [168219 rows x 12 columns]

# %%
# Combine all text from the column into a single string
text = ' '.join(df['Unnamed: 0'])

# Generate the word cloud
wordcloud = WordCloud(width=1000, height=500, background_color='white').generate(text)

# %%
# Display the word cloud using matplotlib
plt.figure(figsize=(20,20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
