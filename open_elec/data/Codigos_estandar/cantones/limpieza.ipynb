# %%
import pandas as pd
import unidecode as ud

# %%
df=pd.read_excel('FINAL_CANTONES.xlsx')
df.drop(['Unnamed: 6','Unnamed: 7', 'Unnamed: 8'], axis=1, inplace=True)
#drop the two last rows
df.drop(df.tail(2).index,inplace=True)
df
# Out:
#      PROVINCIA_CODIGO PROVINCIA_CODIGO_STD       PROVINCIA_NOMBRE  \
# 0                 1.0                  P01                  AZUAY
# 1                 1.0                  P01                  AZUAY
# 2                 1.0                  P01                  AZUAY
# 3                 1.0                  P01                  AZUAY
# 4                 1.0                  P01                  AZUAY
# ..                ...                  ...                    ...
# 269              28.0                  P28  LATAM, CARIBE, AFRICA
# 270              28.0                  P28  LATAM, CARIBE, AFRICA
# 271              28.0                  P28  LATAM, CARIBE, AFRICA
# 272              28.0                  P28  LATAM, CARIBE, AFRICA
# 273              28.0                  P28  LATAM, CARIBE, AFRICA
#
#      CANTON_CODIGO         CANTON_NOMBRE CANTON_CODIGO_STD
# 0            260.0                CUENCA             C0101
# ...

# %%
df.applymap(lambda x: ud.unidecode(x) if type(x) == str else x).to_csv('FINAL_CANTONES.csv', index=False)
# Out:
# C:\Users\saidm\AppData\Local\Temp\ipykernel_27756\2946327189.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: ud.unidecode(x) if type(x) == str else x).to_csv('FINAL_CANTONES.csv', index=False)
