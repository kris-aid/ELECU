# %%
import pandas as pd
import os
import numpy as np

# %%
df_op_names = pd.read_csv('../study_documents/organizaciones/total_organizaciones.csv')
df_op_names
# Out:
#       OP_CODIGO   OP_AMBITO  \
# 0           1.0    NACIONAL
# 1           2.0    NACIONAL
# 2           3.0    NACIONAL
# 3           4.0    NACIONAL
# 4           5.0    NACIONAL
# ...         ...         ...
# 4613     1498.0    CANTONAL
# 4614     1499.0    CANTONAL
# 4615     1500.0  PROVINCIAL
# 4616     1501.0  PROVINCIAL
# 4617     1502.0    CANTONAL
#
#                                               OP_NOMBRE  \
# 0                            PARTIDO UNION NACIONAL UNO
# 1                   PARTIDO LIBERAL RADICAL ECUATORIANO
# 2               PARTIDO SOCIEDAD PATRIOTICA 21 DE ENERO
# 3            PARTIDO CONCENTRACION DE FUERZAS POPULARES
# 4     PARTIDO DEMOCRACIA POPULAR - UNION DEMOCRATA C...
# ...                                                 ...
# 4613                        UNIDOS POR LOS RIOS 1-21-25
# 4614              UNIDOS POR LOS RIOS 1-3-4-20-21-23-25
# 4615             UNIDOS POR LOS RIOS 1-4-17-20-21-23-25
# ...

# %%
df_op_names_nacionales = df_op_names[df_op_names['OP_AMBITO'] == 'NACIONAL']
df_op_names_nacionales
# Out:
#       OP_CODIGO OP_AMBITO                                          OP_NOMBRE  \
# 0           1.0  NACIONAL                         PARTIDO UNION NACIONAL UNO
# 1           2.0  NACIONAL                PARTIDO LIBERAL RADICAL ECUATORIANO
# 2           3.0  NACIONAL            PARTIDO SOCIEDAD PATRIOTICA 21 DE ENERO
# 3           4.0  NACIONAL         PARTIDO CONCENTRACION DE FUERZAS POPULARES
# 4           5.0  NACIONAL  PARTIDO DEMOCRACIA POPULAR - UNION DEMOCRATA C...
# ...         ...       ...                                                ...
# 4156      207.0  NACIONAL           MOVIMIENTO POLITICO REVOLUCION CIUDADANA
# 4157      208.0  NACIONAL  MOVIMIENTO AMIGO, ACCION MOVILIZADORA INDEPEND...
# 4171      222.0  NACIONAL          MOVIMIENTO PUEBLO IGUALDAD DEMOCRACIA PID
# 4175      226.0  NACIONAL                  MOVIMIENTO RENOVACION TOTAL, RETO
# 4180      231.0  NACIONAL                             PARTIDO UNIDAD POPULAR
#
#      OP_SIGLAS  ANIO
# 0     UN - UNO  2002
# ...

# %%
df_op_names_nacionales.to_csv('../study_documents/organizaciones/total_organizaciones_nacionales.csv', index=False)
